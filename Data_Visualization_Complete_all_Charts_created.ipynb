# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as snr

# %%
#loading the iris dataset from sklearn liabrary
iris=snr.load_dataset('iris')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# visualizing the dataset

# %%
#line graph
ax=iris.plot(figsize=(15,8),title='visualization on iris dataset')
ax.set_xlabel('x_axis') #rows
ax.set_ylabel('y_axis') #columns
# Out:
# Text(0, 0.5, 'y_axis')

# %%
#dropping the categorical variable 'species'
data=iris.drop(['species'],axis=1)

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
#bar graph
data.plot(kind='bar')
# Out:
# <Axes: >

# %%
data.iloc[0].plot(kind='bar') #visualization of the 0th row only
# Out:
# <Axes: >

# %%
data.iloc[0].plot(kind='barh') #visualization of the 0th row only
# Out:
# <Axes: >

# %%
data.iloc[35].plot(kind='bar') #visualization of the 35th row only
# Out:
# <Axes: >

# %%
data.iloc[35].plot(kind='barh') #visualization of the 35th row only
# Out:
# <Axes: >

# %%
data.iloc[0:5].plot(kind='bar')
# Out:
# <Axes: >

# %%
data.iloc[0:5].plot(kind='barh')
# Out:
# <Axes: >

# %%
data.iloc[15:20].plot(kind='bar')
# Out:
# <Axes: >

# %%
#histogram
data.diff().plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['sepal_length'].diff().plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['petal_length'].diff().plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['sepal_width'].diff().plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['petal_width'].diff().plot(kind='hist',bins=200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
data.plot.pie(subplots=True, figsize=(10,10))
# Out:
# array([<Axes: ylabel='sepal_length'>, <Axes: ylabel='sepal_width'>,
#        <Axes: ylabel='petal_length'>, <Axes: ylabel='petal_width'>],
#       dtype=object)

# %%
#pie chart
d=data.iloc[0] #pie chart using the 0th row only

# %%
d.plot.pie(figsize=(10,10),fontsize=15, autopct='%.2f')
# Out:
# <Axes: ylabel='0'>

# %%
d=data.iloc[100]

# %%
d.plot.pie(figsize=(10,10),fontsize=15, autopct='%.2f')
# Out:
# <Axes: ylabel='100'>

# %%
d=data.iloc[0:3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f4096ff9d5ed> in <cell line: 1>()
# ----> 1 d=data.iloc[0:3]
#
# NameError: name 'data' is not defined

# %%
d.plot.pie(subplots=True, figsize=(10,10),fontsize=10,autopct='%.2f')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1c3425ca5f73> in <cell line: 1>()
# ----> 1 d.plot.pie(subplots=True, figsize=(10,10),fontsize=10,autopct='%.2f')
#
# NameError: name 'd' is not defined

# %% [markdown]
# Advanced Visualization
#
# 1. Scatter plot
#
# 2. Relational plot
#
# 3. Categorical plot
#
# 4. Box plot
#
# 5. Pair plot
#
# 6. Heatmap

# %%
#scatter plot
data.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
data.plot.scatter(x='petal_length',y='petal_width', color='r')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
data.plot.scatter(x='sepal_length',y='sepal_width', color='g')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
data.plot.scatter(x='petal_length',y='petal_width', c='sepal_width')
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
import numpy as np
import pandas as pd

# %%
data_new=pd.read_csv("/content/tips.csv")

# %%
data_new.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#relplot
snr.relplot(x='total_bill',y='sex',data=data_new)

# %%
snr.relplot(x='tip',y='sex',data=data_new)

# %%
snr.relplot(x='total_bill',y='tip', hue='smoker',data=data_new)

# %%
snr.relplot(x='total_bill',y='tip', hue='sex',data=data_new)

# %%
snr.relplot(x='total_bill',y='tip', hue='smoker', style='time', data=data_new)

# %%
snr.relplot(x='total_bill',y='tip', hue='smoker', style='time', col='sex', data=data_new)

# %%
snr.relplot(x='total_bill',y='tip', hue='smoker', style='sex', col='time', data=data_new)

# %%
snr.relplot(x='total_bill',y='tip', hue='smoker', style='time', size='size', data=data_new)

# %%
#catplot
snr.catplot(x='total_bill',y='day',data=data_new)

# %%
snr.catplot(x='tip',y='time',data=data_new)

# %%
snr.catplot(x='tip',y='sex',data=data_new)

# %%
#boxplot
snr.catplot(x='day',y='tip',kind='box',hue='sex',data=data_new)

# %%
#pair plot
snr.pairplot(data_new,x_vars=['tip','sex','time'],y_vars=['total_bill'],size=10)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#heatmap - will show the corelation between different features
plt.figure(figsize=(5,5))
snr.heatmap(data_new.corr(),annot=True)
# Out:
# <ipython-input-58-57b6f1425e13>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   snr.heatmap(data_new.corr(),annot=True)
# <Axes: >
